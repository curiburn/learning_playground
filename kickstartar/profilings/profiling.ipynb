# %%
import pandas as pd
import sweetviz as sv

# %%
from transforms.dataframes.preprocess import dataframe_preprocess

DATA = dataframe_preprocess(pd.read_csv("data/kickstarter.csv"))
display(DATA)
display(DATA.describe())
# Out:
#                 ID                                               name  \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2       1000004038                                     Where is Hank?
# 3       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4       1000011046  Community Film Project: The Art of Neighborhoo...
# ...            ...                                                ...
# 378649   999976400  ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 378650   999977640                                          The Tribe
# 378651   999986353  Walls of Remedy- New lesbian Romantic Comedy f...
# 378652   999987933                           BioDefense Education Kit
# 378653   999988282                  Nou Renmen Ayiti!  We Love Haiti!
#
#        main_category     sub_category         country currency  \
# ...

# %%
DATA.dtypes
# Out:
# ID                                int64
# name                             object
# main_category                    object
# sub_category                     object
# country                          object
# currency                         object
# launched            datetime64[ns, UTC]
# deadline                         object
# goal                            float64
# pledged                         float64
# backers                           int64
# usd_pledged_real                float64
# usd_goal_real                   float64
# status                           object
# dtype: object

# %%
display(DATA.status.unique())
# Out:
# array(['failed', 'canceled', 'successful', 'live', 'undefined',
#        'suspended'], dtype=object)

# %%
report = sv.analyze(DATA)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
report.show_notebook()
# Out:
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.4.1 | (c) JS Foundation and other contributors | jquery.org/license */
# ...

# %% [markdown]
# そもそもdatetimeがstringのままなことに気づいた
#
# ~~preprocessとしてparseしてあげたほうが良さそう。（そして、もっかいprofilingしよう）~~ <- やった
